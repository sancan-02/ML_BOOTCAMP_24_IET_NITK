# %% [markdown]
# # 🧑‍🏫 Task 1 Part 1: Building a Spam Classifier with Naive Bayes
# In this exercise, you'll implement a spam classifier using the **Naive Bayes algorithm** . You'll work with email data to classify messages as spam or non-spam (ham). Follow the steps below and fill in the code where indicated.
#
# **Objective:** Implement all key components of an ML pipeline (except for data handling).
#
# **Allowed Libraries:** `pandas`, `numpy`
#
# **Not Allowed:** Any pre-built ML algorithms or functions like those from `sklearn`.
#
# Follow the instructions step-by-step and answer the questions!

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# ## Step 1: Data Loading and Preprocessing
# First, let's load and examine our data.

# %%
# Load the data
# wODO: Load the 'emails.csv' file into a DataFrame called 'emails'
emails = pd.read_csv("emails.csv")

# %%
# Display the first few rows
print(emails.head())

# HINT: Use pd.read_csv() to load the data
# HINT: The DataFrame should have 'text' and 'spam' columns
# Out:
#                                                 text  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
#Analyse the data and remove or modify rows with missing or invalid values
emails.dropna(inplace=True)

for x in emails["spam"]:
    if x != 1 or x != 0:
        emails.dropna(inplace=True)

# %%
emails = emails.drop(emails.index[1000:4000])
emails
# Out:
#                                                    text  spam
# 90    Subject: investment / partnership proposal  de...     1
# 1583  Subject: re : executive program on credit risk...     0
# 1999  Subject: the february issue of reactions is no...     0
# 2501  Subject: re : stanford or - summer interns  ra...     0
# 1206  Subject: all graphics software available , che...     1
# ...                                                 ...   ...
# 5568  Subject: re : var for cob 2 nd aug 2000  hi ki...     0
# 5215  Subject: re : risk european energy 2000  steve...     0
# 1424  Subject: re :  gordon ,  it was a pleasure tal...     0
# 4012  Subject: confirmation of 3 / 20 9 a . m . meet...     0
# 1926  Subject: re : energy derivative courses  fyi  ...     0
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## Step 2: Text Preprocessing
# We need to process each email to extract unique words.

# %%
def process_email(text):
    """
    Convert email text to a list of unique, lowercase words
    
    Parameters:
        text (str): The email text
    
    Returns:
        list: List of unique words in the email
    """
    # TODO: Implement the preprocessing function
    # 1. Convert text to lowercase
    # 2. Split into words
    # 3. Remove duplicates

    # Your code here
    text = text.lower()
    text = text.split()
    text = set(text)
    text = list(text)
    
    return text
    # HINT: Use text.lower() for lowercase conversion
    # HINT: Use split() to convert text to words
    # HINT: Use set() to remove duplicates
    pass

# %%
# Apply preprocessing to all emails
words = set()
for x in emails["text"]:
    x = process_email(x)
    words.update(x)

# %%
words
# Out:
# {'phd',
#  'exhibitions',
#  'cousin',
#  'xx',
#  'smaller',
#  'designers',
#  'jhenders',
#  'paez',
#  'white',
#  'mason',
#  '5701',
#  'hrgovcic',
#  'queue',
#  'flow',
#  '1965',
#  'dissemination',
#  'systemworks',
#  'breen',
#  'cbn',
#  'jgsm',
#  'issures',
#  '4727',
#  '8511',
#  'wess',
#  'v',
#  'accommodations',
#  'prosilbym',
#  'margin',
#  'teaser',
#  'talked',
#  'head',
#  'adjustment',
#  'benefits',
#  'deteriorated',
#  'lub',
#  'marquardt',
#  'crenshawwrote',
#  '3458',
#  'aps',
#  'hsbcib',
#  'fabulous',
#  'arguments',
#  'suited',
#  'sandbox',
#  'satisfaction',
#  '2938',
#  'karnataka',
#  '35275',
#  'affiliates',
#  'stockholder',
#  'hmuprzd',
#  'centered',
#  'mornings',
#  'nrumqor',
#  '290',
#  'ghosh',
#  'training',
#  '11',
#  'autience',
#  '1936',
#  'layton',
#  'wieloma',
#  'detail',
#  '0587',
#  'bulletin',
#  '40',
#  'risckrac',
#  'realign',
#  'tune',
#  'engage',
#  'costs',
#  'pd',
#  'tale',
#  '5728',
#  '4234',
#  'grateful',
#  'bd',
#  'chaxel',
#  'penis',
#  'dating',
#  'pressurising',
#  'typesetters',
#  'arbitrage',
#  '6761',
#  'tconvery',
#  'soc',
#  'jakie',
#  'inconsistent',
#  'properly',
#  'network',
#  'tten',
#  'track',
#  'christina',
#  'disk',
#  'startbgmlmezine',
#  'fwd',
#  'camoglum',
#  '8227',
#  'originals',
#  'constructing',
#  'rgob',
#  'adres',
#  '81018216102',
#  'validate',
#  'powertechlabs',
#  'jeanette',
#  'gustavo',
#  'ture',
#  'spruce',
#  'ahamer',
#  'unpaid',
#  '762',
#  '6374',
#  'oliver',
#  'specifics',
#  '134',
#  'thirty',
#  'panie',
#  'swaps',
#  'each',
#  'page',
#  'overholt',
#  'publishes',
#  'representing',
#  'motherboards',
#  'dreamweaver',
#  'mmbtu',
#  'tidal',
#  'aggregating',
#  'inform',
#  'enabled',
#  'jody',
#  'thereon',
#  'businesses',
#  'lllustrator',
#  'variables',
#  'tocqueville',
#  'imbalances',
#  'merger',
#  'phare',
#  'tentative',
#  'parting',
#  'lliana',
#  'accountability',
#  'credible',
#  'negotiations',
#  'dsouza',
#  '4601',
#  '2836',
#  'trading',
#  'hgh',
#  '10006',
#  'settled',
#  'lme',
#  'ranendra',
#  'poconos',
#  'yyyy',
#  'flexible',
#  'sue',
#  '4704',
#  'alliances',
#  'behaviour',
#  'ca',
#  'marquez',
#  'winston',
#  'lghz',
#  'casewriting',
#  'pops',
#  'round',
#  'mulong',
#  'impacted',
#  'neat',
#  'aep',
#  '355',
#  'anxious',
#  'ridden',
#  'ast',
#  'cinema',
#  'exams',
#  '600',
#  '77',
#  'alot',
#  '619',
#  'slected',
#  '506',
#  '102',
#  'curran',
#  '953',
#  'inheritor',
#  'personal',
#  'inconvinence',
#  'advantages',
#  'possibilities',
#  'demianenko',
#  'lakes',
#  'gpg',
#  'dispose',
#  'edsono',
#  'giancola',
#  'holyoke',
#  'sims',
#  'sufficient',
#  'internship',
#  'pratt',
#  'timekeeper',
#  'plain',
#  'preferred',
#  'differences',
#  'pomysl',
#  'hey',
#  'origin',
#  'bagha',
#  'rico',
#  'retired',
#  'rhetorically',
#  'ineternet',
#  'priorities',
#  'mat',
#  'spinning',
#  'interactions',
#  'calibrated',
#  'reciba',
#  'meant',
#  'accomplishing',
#  'or',
#  'innovation',
#  'present',
#  'intruments',
#  'investigates',
#  'mile',
#  'inconvenience',
#  'accomplishment',
#  'inland',
#  'receive',
#  'basics',
#  'compatibility',
#  'pledelo',
#  'canadian',
#  'tried',
#  'uses',
#  'egypthttp',
#  'labbe',
#  'specialising',
#  'binary',
#  'mistake',
#  'repayment',
#  'studying',
#  'gielda',
#  'people',
#  'corresponding',
#  'loss',
#  'encotech',
#  'dpi',
#  '1994',
#  'daetz',
#  'backpack',
#  'shows',
#  'practicable',
#  'contract',
#  'accommodation',
#  'score',
#  'ourlast',
#  'naturally',
#  'ordinates',
#  'luitgard',
#  '5670',
#  'salmon',
#  'successful',
#  'dip',
#  'wesley',
#  'adv',
#  'bound',
#  'hispanic',
#  'bouillion',
#  'jonathan',
#  'suc',
#  'janie',
#  'glued',
#  'arsenal',
#  '271679',
#  'noemi',
#  'monetary',
#  'performing',
#  'dlcations',
#  'stationer',
#  'parquet',
#  'filter',
#  '5377',
#  'assumed',
#  '051102',
#  'diffusions',
#  'ebt',
#  'make',
#  'bring',
#  'multiply',
#  'ginge',
#  'rvs',
#  'screening',
#  'twenty',
#  'shi',
#  'argument',
#  'deadline',
#  '8980',
#  'cal',
#  'correction',
#  'reaiized',
#  'irs',
#  'hammers',
#  'reception',
#  'hall',
#  '0313',
#  'teknecon',
#  'tc',
#  'leftwing',
#  'downsize',
#  'transactional',
#  'chello',
#  'canyon',
#  'dinner',
#  'replacement',
#  'commonwealth',
#  'pride',
#  'likelihood',
#  'bearing',
#  'elahi',
#  'family',
#  'inforamtion',
#  'seconds',
#  'raised',
#  'ana',
#  'sees',
#  'persuaded',
#  'refinery',
#  '563',
#  'dysfunction',
#  'quaintance',
#  '972',
#  'total',
#  'ncsu',
#  'sur',
#  'mansfield',
#  'richest',
#  'additional',
#  'esource',
#  'specialised',
#  'stationery',
#  'xnd',
#  'pledged',
#  'located',
#  'outlook',
#  'monetized',
#  'flexdex',
#  'forty',
#  'chimney',
#  '5230',
#  'square',
#  'negotiator',
#  'linoleum',
#  'recognise',
#  'cancelled',
#  'buildinq',
#  'conceit',
#  'netherlands',
#  '1955',
#  'growthwrinkle',
#  '144',
#  '7917',
#  'jeden',
#  'achievements',
#  'lara',
#  'iot',
#  'usership',
#  'busch',
#  'town',
#  'kristi',
#  'rgbaz',
#  'begun',
#  'piazze',
#  'shipments',
#  'nat',
#  '6073',
#  'copia',
#  '324',
#  'manageable',
#  'burkhart',
#  'lattices',
#  'room',
#  '5967',
#  'buiiding',
#  'benjamin',
#  'annual',
#  'aol',
#  'signers',
#  'nesbitt',
#  'ots',
#  'cypress',
#  'thereafter',
#  'officers',
#  'mrs',
#  'n',
#  'fa',
#  'everyday',
#  '2050',
#  'sinha',
#  '410',
#  'indicative',
#  'aleksandra',
#  'analiza',
#  'wq',
#  'ciick',
#  'default',
#  'mepr',
#  'upgrades',
#  'pimbley',
#  'paramount',
#  'consequence',
#  'emanating',
#  '5243',
#  'whitt',
#  'evident',
#  'rod',
#  'sites',
#  'data',
#  'admiration',
#  'shane',
#  'crawling',
#  'crisp',
#  'hendon',
#  'blade',
#  'batchelder',
#  'disadvantaged',
#  'miilions',
#  'wireless',
#  'smile',
#  'swags',
#  'previously',
#  'audio',
#  'edson',
#  'sweet',
#  'mrongovia',
#  'bucket',
#  'tayana',
#  '921',
#  'agentur',
#  'charged',
#  'outagerisk',
#  'recreate',
#  'olbrzymie',
#  'touche',
#  'hires',
#  'lasting',
#  'social',
#  'cracks',
#  'dd',
#  'exeloncorp',
#  'removes',
#  'unlimited',
#  'removed',
#  'bbo',
#  '2184',
#  'problams',
#  'rhythm',
#  'whether',
#  'recepci?n',
#  'graduated',
#  '3585',
#  'fell',
#  'residents',
#  'encouraged',
#  'hsb',
#  '8877',
#  'learned',
#  'describes',
#  'ground',
#  '072',
#  'grades',
#  'italy',
#  'mediagroup',
#  'cooperation',
#  'inconstant',
#  'indirect',
#  'nxho',
#  'estimating',
#  'doliars',
#  'confidentiai',
#  'nearing',
#  'banded',
#  'robbed',
#  'netnoteinc',
#  'tristategt',
#  'foil',
#  'suite',
#  'mind',
#  'mailman',
#  'society',
#  'balloting',
#  'fiala',
#  '95',
#  'sp',
#  'thomsen',
#  'qualitative',
#  'lamas',
#  'serverhave',
#  'emarketplace',
#  'participacion',
#  'enhances',
#  'felecia',
#  'sas',
#  'yaron',
#  'jane',
#  'climate',
#  'mordaunt',
#  'cynthia',
#  'tracks',
#  'popularity',
#  'thing',
#  'prioritization',
#  'brave',
#  'isbn',
#  'capturing',
#  'gardens',
#  'dwr',
#  'instructional',
#  'blow',
#  'prepare',
#  'scicomp',
#  'fazie',
#  'heding',
#  'dwivedi',
#  'sxn',
#  'unlawful',
#  'warned',
#  'absolutely',
#  'mgm',
#  'light',
#  'seek',
#  'bassalo',
#  'curry',
#  'meg',
#  'analysed',
#  'aluminium',
#  'mercedes',
#  'qualities',
#  'alerted',
#  'further',
#  'justice',
#  '666',
#  'spreadsheet',
#  'ibm',
#  'founding',
#  'develop',
#  '7',
#  'wade',
#  'mantua',
#  '73',
#  '321',
#  'confidenti',
#  'lateral',
#  'overtime',
#  'dose',
#  'met',
#  'paradigm',
#  'quarries',
#  'jetlow',
#  'weekday',
#  'translation',
#  'mba',
#  'deakin',
#  '9326',
#  'strategic',
#  'enroll',
#  'engr',
#  'felix',
#  'corteselli',
#  'logodentity',
#  'task',
#  'walks',
#  'circular',
#  '>',
#  'perlman',
#  'discriminating',
#  'disability',
#  'keller',
#  'gaps',
#  'flying',
#  'pierce',
#  'tremendously',
#  'finalized',
#  'onshore',
#  'gutierrez',
#  'cusom',
#  'growth',
#  'lengthy',
#  'aproximately',
#  'survive',
#  '6429',
#  'may',
#  'former',
#  '7626',
#  'vehicle',
#  'stoked',
#  'blame',
#  'sager',
#  'prediction',
#  'llp',
#  'dengie',
#  'manifolds',
#  'simpson',
#  'says',
#  'lipscomb',
#  'most',
#  'forecast',
#  'organise',
#  '181',
#  'bet',
#  'sherri',
#  'johns',
#  '33461428',
#  'chauvet',
#  '5650',
#  'hurry',
#  'segments',
#  'comparably',
#  '6995',
#  'mou',
#  'postion',
#  'tao',
#  'condone',
#  'hbrett',
#  'simulation',
#  'fifty',
#  'devastating',
#  'henry',
#  'wex',
#  'ftp',
#  'proxy',
#  'ability',
#  '396',
#  'fast',
#  'opt',
#  'millions',
#  'tracey',
#  'libidoduration',
#  'handful',
#  'spamassassin',
#  'firmly',
#  '31881',
#  '271595',
#  'basak',
#  '200',
#  'bureau',
#  'yana',
#  'photograph',
#  'clauura',
#  'restricted',
#  'sequential',
#  'models',
#  'hungary',
#  'programmed',
#  'conferences',
#  'govern',
#  'alcohoi',
#  'preserve',
#  'projecct',
#  'oranjestad',
#  'selections',
#  'brainstorming',
#  'shuttle',
#  'immortal',
#  'sexually',
#  'qfs',
#  'judgement',
#  'forth',
#  'rcpt',
#  'mayo',
#  'verbally',
#  'credittrading',
#  'spoofed',
#  'musialem',
#  'discreetly',
#  'committed',
#  'lost',
#  'informational',
#  'showcase',
#  'powered',
#  'srs',
#  'designing',
#  'wspolpracujemy',
#  'explains',
#  'powerisk',
#  'thorne',
#  'bjk',
#  'quirke',
#  'indicator',
#  'jed',
#  'protocols',
#  'passage',
#  'creditor',
#  'salomon',
#  'deficits',
#  'orlando',
#  'construction',
#  'reza',
#  'pulpit',
#  'rated',
#  'downloaded',
#  'glenn',
#  'info',
#  'convictions',
#  '6861',
#  'scrapped',
#  'adoption',
#  '6855',
#  'breed',
#  'sec',
#  'hopley',
#  'frankmullers',
#  'with',
#  '020',
#  'addiontionally',
#  'kmv',
#  '6032',
#  '780',
#  'call',
#  'foundations',
#  'logos',
#  'shared',
#  'dollie',
#  'hang',
#  'destination',
#  'esai',
#  '1992',
#  'central',
#  'fee',
#  'conscious',
#  'windle',
#  'limited',
#  'equation',
#  'surrejoinder',
#  'omit',
#  'deffner',
#  'cindy',
#  'blows',
#  'fbdxq',
#  '2372',
#  'understated',
#  'energydesk',
#  '0100',
#  'jim',
#  'markus',
#  'trs',
#  'migration',
#  'late',
#  'garrett',
#  'forit',
#  'activities',
#  'phrase',
#  'arm',
#  'monitors',
#  'cialls',
#  'stephen',
#  'bermudian',
#  'aircrafts',
#  'weekend',
#  'woefully',
#  '02',
#  'bonus',
#  'shankman',
#  'trials',
#  'congressional',
#  'houstonu',
#  'hurt',
#  'scheduling',
#  'sweetness',
#  'sectors',
#  'weil',
#  'nazareth',
#  'sealed',
#  'hickerson',
#  'typesetter',
#  '100',
#  'intended',
#  'set',
#  'taichi',
#  'mississippi',
#  'etei',
#  'characterize',
#  'unhand',
#  'flawed',
#  'bigaaron',
#  'vicky',
#  'mckone',
#  'marine',
#  'relaxed',
#  'might',
#  '2965',
#  'bidding',
#  'esaulle',
#  'calpine',
#  'intermediation',
#  'india',
#  'reputation',
#  'adler',
#  '2258',
#  'freeman',
#  '339',
#  'acquisition',
#  'drop',
#  'xiao',
#  'rational',
#  '135',
#  'endowed',
#  'sharply',
#  'auctioning',
#  'bruce',
#  '8738',
#  'reaction',
#  'festivities',
#  'represented',
#  'ymjg',
#  'simon',
#  '6592',
#  'laser',
#  'grabstald',
#  'syed',
#  'historical',
#  'b',
#  'gvj',
#  'slapped',
#  'entrants',
#  'ordering',
#  'acpw',
#  'meaningful',
#  'przed',
#  'lew',
#  'terminating',
#  'organizer',
#  'smartmortgageusa',
#  'obi',
#  'resumes',
#  'cop',
#  'fall',
#  'grand',
#  'pecos',
#  'ob',
#  'ionqing',
#  'swisher',
#  'must',
#  '4592',
#  'twice',
#  'wants',
#  'charities',
#  'competing',
#  'px',
#  'turn',
#  'kulatilaka',
#  'demise',
#  'reliantenergy',
#  'gwyn',
#  'stainlessteelbody',
#  'warranty',
#  '7517',
#  'pgpfreeware',
#  'scout',
#  'escape',
#  'subscribe',
#  'some',
#  'guaiity',
#  '7260',
#  'diversification',
#  'chodzi',
#  'russell',
#  'cliff',
#  'table',
#  '33145',
#  'mer',
#  'develoment',
#  'asp',
#  'monte',
#  'stearns',
#  'offered',
#  'underlyings',
#  '43',
#  'blaming',
#  '9611',
#  'lesley',
#  'distribute',
#  'amex',
#  'getting',
#  'fis',
#  'muscle',
#  'sa',
#  'wealth',
#  'nate',
#  '24406',
#  'sept',
#  'developed',
#  'undone',
#  'wkshp',
#  'herein',
#  'proportionately',
#  'acknowledgement',
#  'brysonpa',
#  'authorization',
#  'kirby',
#  'tender',
#  'chemist',
#  'bumps',
#  '244',
#  'roch',
#  'wykorzystywanych',
#  'alterations',
#  'georgel',
#  'ceska',
#  'pioneers',
#  'north',
#  'interested',
#  'actually',
#  'confidencialidad',
#  'letter',
#  'earliest',
#  'toy',
#  'deposits',
#  'investigate',
#  '8850',
#  'buynxlc',
#  'finalizing',
#  '626',
#  'hq',
#  '954',
#  'closet',
#  'kindall',
#  'fuel',
#  'undoubtedly',
#  'enel',
#  'solved',
#  'carolina',
#  'reliable',
#  'evan',
#  'structured',
#  'suites',
#  'schoemaker',
#  'mw',
#  'akin',
#  'turnaround',
#  'airport',
#  'habiba',
#  'dailyupdate',
#  'coveted',
#  'sin',
#  'leakages',
#  'ation',
#  'appears',
#  '62',
#  'sengupta',
#  'maxed',
#  'lightning',
#  'abacus',
#  'stuffed',
#  'boldly',
#  'hoog',
#  'sycamore',
#  'drugie',
#  'unequal',
#  'began',
#  'why',
#  'treading',
#  'pdt',
#  'reflect',
#  'wiley',
#  'west',
#  'degiacic',
#  'abide',
#  'paths',
#  'hara',
#  'tasks',
#  'omnicom',
#  'keeping',
#  'iom',
#  '349',
#  'slippery',
#  'krogmeier',
#  'decrement',
#  'publish',
#  'revolutionize',
#  'advisor',
#  'royalties',
#  'fri',
#  'fullest',
#  'drinks',
#  '4026',
#  'woodybc',
#  'rosenkopf',
#  'spice',
#  '34073',
#  'econometric',
#  'machines',
#  'ms',
#  'elo',
#  'macromedia',
#  ...}

# %%
type(words)
# Out:
# set

# %% [markdown]
# ## Step 3: Calculate Prior Probabilities
# Let's calculate the basic probability of an email being spam.

# %%
# TODO: Calculate the following:
# 1. Total number of emails
# 2. Number of spam emails
# 3. Probability of spam

num_emails = len(emails["text"])

num_spam = 0
for x in emails["spam"]:
    if x == 1:
        num_spam= num_spam+1
        
spam_probability = num_spam/num_emails

print(f"Number of emails: {num_emails}")
print(f"Number of spam emails: {num_spam}")
num_ham = num_emails-num_spam
print(f"Probability of spam: {spam_probability:.4f}")

# HINT: Use len(emails) for total count
# HINT: Use sum(emails['spam']) for spam count
# Out:
# Number of emails: 1000
# Number of spam emails: 217
# Probability of spam: 0.2170

# %% [markdown]
# ## Step 4: Training the Model
# Now we'll build our Naive Bayes model by counting word occurrences in spam and ham emails.

# %%
def train_naive_bayes(words):
    """
    Train a Naive Bayes model on email data
    
    Parameters:
        emails_data (DataFrame): DataFrame with 'words' and 'spam' columns
    
    Returns:
        dict: Dictionary with word frequencies in spam and ham emails
    """
    # TODO: Create a dictionary to store word frequencies
    # For each word, store counts of its occurrence in spam and ham emails
    model = {}
    
    
    for x in words:
        model[x] = {"spam": 0, "ham": 0}
        for i in emails["text"]:
            if i.find(x) != -1:
                k = emails[emails['text']== i].index.values.astype(int)[0]
                if (emails["spam"][k]) == 1:
                    model[x]["spam"] +=1 
                elif (emails["spam"][k]) == 0:
                    model[x]["ham"] +=1
        
             # if word occured more than once then calculate no. of 

    # Your code here
    # HINT: Initialize counts with 1 (Laplace smoothing)
    # HINT: Structure: model[word] = {'spam': count, 'ham': count}

    return model

# %%
words = list(words)

# %%
model = train_naive_bayes(words)

# %%
model
# Out:
# {'phd': {'spam': 1, 'ham': 17},
#  'exhibitions': {'spam': 1, 'ham': 0},
#  'cousin': {'spam': 0, 'ham': 1},
#  'xx': {'spam': 3, 'ham': 3},
#  'smaller': {'spam': 1, 'ham': 4},
#  'designers': {'spam': 1, 'ham': 0},
#  'jhenders': {'spam': 0, 'ham': 1},
#  'paez': {'spam': 0, 'ham': 1},
#  'white': {'spam': 2, 'ham': 3},
#  'mason': {'spam': 1, 'ham': 3},
#  '5701': {'spam': 0, 'ham': 1},
#  'hrgovcic': {'spam': 0, 'ham': 6},
#  'queue': {'spam': 0, 'ham': 1},
#  'flow': {'spam': 1, 'ham': 19},
#  '1965': {'spam': 0, 'ham': 1},
#  'dissemination': {'spam': 1, 'ham': 2},
#  'systemworks': {'spam': 1, 'ham': 0},
#  'breen': {'spam': 0, 'ham': 1},
#  'cbn': {'spam': 1, 'ham': 0},
#  'jgsm': {'spam': 0, 'ham': 3},
#  'issures': {'spam': 0, 'ham': 1},
#  '4727': {'spam': 0, 'ham': 3},
#  '8511': {'spam': 0, 'ham': 1},
#  'wess': {'spam': 0, 'ham': 2},
#  'v': {'spam': 211, 'ham': 771},
#  'accommodations': {'spam': 0, 'ham': 1},
#  'prosilbym': {'spam': 0, 'ham': 1},
#  'margin': {'spam': 2, 'ham': 5},
#  'teaser': {'spam': 0, 'ham': 1},
#  'talked': {'spam': 0, 'ham': 18},
#  'head': {'spam': 12, 'ham': 77},
#  'adjustment': {'spam': 1, 'ham': 4},
#  'benefits': {'spam': 10, 'ham': 13},
#  'deteriorated': {'spam': 1, 'ham': 1},
#  'lub': {'spam': 0, 'ham': 10},
#  'marquardt': {'spam': 0, 'ham': 1},
#  'crenshawwrote': {'spam': 0, 'ham': 1},
#  '3458': {'spam': 0, 'ham': 1},
#  'aps': {'spam': 11, 'ham': 40},
#  'hsbcib': {'spam': 0, 'ham': 1},
#  'fabulous': {'spam': 1, 'ham': 1},
#  'arguments': {'spam': 0, 'ham': 1},
#  'suited': {'spam': 0, 'ham': 5},
#  'sandbox': {'spam': 0, 'ham': 1},
#  'satisfaction': {'spam': 11, 'ham': 1},
#  '2938': {'spam': 0, 'ham': 1},
#  'karnataka': {'spam': 0, 'ham': 1},
#  '35275': {'spam': 0, 'ham': 1},
#  'affiliates': {'spam': 1, 'ham': 0},
#  'stockholder': {'spam': 1, 'ham': 0},
#  'hmuprzd': {'spam': 1, 'ham': 0},
#  'centered': {'spam': 0, 'ham': 1},
#  'mornings': {'spam': 0, 'ham': 3},
#  'nrumqor': {'spam': 0, 'ham': 1},
#  '290': {'spam': 1, 'ham': 30},
#  'ghosh': {'spam': 0, 'ham': 4},
#  'training': {'spam': 4, 'ham': 23},
#  '11': {'spam': 26, 'ham': 207},
#  'autience': {'spam': 0, 'ham': 1},
#  '1936': {'spam': 0, 'ham': 1},
#  'layton': {'spam': 0, 'ham': 14},
#  'wieloma': {'spam': 0, 'ham': 1},
#  'detail': {'spam': 21, 'ham': 67},
#  '0587': {'spam': 0, 'ham': 2},
#  'bulletin': {'spam': 0, 'ham': 3},
#  '40': {'spam': 21, 'ham': 118},
#  'risckrac': {'spam': 0, 'ham': 1},
#  'realign': {'spam': 0, 'ham': 2},
#  'tune': {'spam': 9, 'ham': 4},
#  'engage': {'spam': 1, 'ham': 8},
#  'costs': {'spam': 5, 'ham': 15},
#  'pd': {'spam': 13, 'ham': 93},
#  'tale': {'spam': 0, 'ham': 19},
#  '5728': {'spam': 0, 'ham': 1},
#  '4234': {'spam': 0, 'ham': 1},
#  'grateful': {'spam': 0, 'ham': 4},
#  'bd': {'spam': 3, 'ham': 3},
#  'chaxel': {'spam': 0, 'ham': 1},
#  'penis': {'spam': 3, 'ham': 0},
#  'dating': {'spam': 0, 'ham': 7},
#  'pressurising': {'spam': 0, 'ham': 1},
#  'typesetters': {'spam': 0, 'ham': 1},
#  'arbitrage': {'spam': 0, 'ham': 3},
#  '6761': {'spam': 0, 'ham': 1},
#  'tconvery': {'spam': 0, 'ham': 1},
#  'soc': {'spam': 12, 'ham': 82},
#  'jakie': {'spam': 0, 'ham': 1},
#  'inconsistent': {'spam': 0, 'ham': 1},
#  'properly': {'spam': 2, 'ham': 1},
#  'network': {'spam': 4, 'ham': 27},
#  'tten': {'spam': 14, 'ham': 111},
#  'track': {'spam': 7, 'ham': 14},
#  'christina': {'spam': 0, 'ham': 1},
#  'disk': {'spam': 2, 'ham': 3},
#  'startbgmlmezine': {'spam': 1, 'ham': 0},
#  'fwd': {'spam': 1, 'ham': 18},
#  'camoglum': {'spam': 0, 'ham': 1},
#  '8227': {'spam': 0, 'ham': 1},
#  'originals': {'spam': 1, 'ham': 0},
#  'constructing': {'spam': 2, 'ham': 0},
#  'rgob': {'spam': 0, 'ham': 1},
#  'adres': {'spam': 0, 'ham': 2},
#  '81018216102': {'spam': 1, 'ham': 0},
#  'validate': {'spam': 1, 'ham': 1},
#  'powertechlabs': {'spam': 0, 'ham': 1},
#  'jeanette': {'spam': 0, 'ham': 3},
#  'gustavo': {'spam': 0, 'ham': 2},
#  'ture': {'spam': 59, 'ham': 163},
#  'spruce': {'spam': 0, 'ham': 1},
#  'ahamer': {'spam': 0, 'ham': 1},
#  'unpaid': {'spam': 1, 'ham': 0},
#  '762': {'spam': 0, 'ham': 3},
#  '6374': {'spam': 0, 'ham': 1},
#  'oliver': {'spam': 0, 'ham': 3},
#  'specifics': {'spam': 0, 'ham': 3},
#  '134': {'spam': 1, 'ham': 2},
#  'thirty': {'spam': 4, 'ham': 3},
#  'panie': {'spam': 16, 'ham': 36},
#  'swaps': {'spam': 0, 'ham': 11},
#  'each': {'spam': 15, 'ham': 124},
#  'page': {'spam': 16, 'ham': 40},
#  'overholt': {'spam': 0, 'ham': 1},
#  'publishes': {'spam': 1, 'ham': 0},
#  'representing': {'spam': 0, 'ham': 4},
#  'motherboards': {'spam': 1, 'ham': 0},
#  'dreamweaver': {'spam': 4, 'ham': 0},
#  'mmbtu': {'spam': 0, 'ham': 1},
#  'tidal': {'spam': 1, 'ham': 0},
#  'aggregating': {'spam': 0, 'ham': 2},
#  'inform': {'spam': 55, 'ham': 200},
#  'enabled': {'spam': 0, 'ham': 2},
#  'jody': {'spam': 1, 'ham': 2},
#  'thereon': {'spam': 0, 'ham': 1},
#  'businesses': {'spam': 4, 'ham': 13},
#  'lllustrator': {'spam': 1, 'ham': 0},
#  'variables': {'spam': 0, 'ham': 2},
#  'tocqueville': {'spam': 0, 'ham': 1},
#  'imbalances': {'spam': 0, 'ham': 1},
#  'merger': {'spam': 0, 'ham': 4},
#  'phare': {'spam': 0, 'ham': 1},
#  'tentative': {'spam': 0, 'ham': 10},
#  'parting': {'spam': 1, 'ham': 0},
#  'lliana': {'spam': 1, 'ham': 0},
#  'accountability': {'spam': 1, 'ham': 2},
#  'credible': {'spam': 6, 'ham': 1},
#  'negotiations': {'spam': 0, 'ham': 5},
#  'dsouza': {'spam': 0, 'ham': 1},
#  '4601': {'spam': 0, 'ham': 1},
#  '2836': {'spam': 0, 'ham': 1},
#  'trading': {'spam': 5, 'ham': 80},
#  'hgh': {'spam': 3, 'ham': 0},
#  '10006': {'spam': 0, 'ham': 1},
#  'settled': {'spam': 1, 'ham': 3},
#  'lme': {'spam': 3, 'ham': 30},
#  'ranendra': {'spam': 0, 'ham': 1},
#  'poconos': {'spam': 0, 'ham': 1},
#  'yyyy': {'spam': 1, 'ham': 1},
#  'flexible': {'spam': 0, 'ham': 3},
#  'sue': {'spam': 9, 'ham': 115},
#  '4704': {'spam': 0, 'ham': 2},
#  'alliances': {'spam': 0, 'ham': 4},
#  'behaviour': {'spam': 0, 'ham': 1},
#  'ca': {'spam': 157, 'ham': 658},
#  'marquez': {'spam': 0, 'ham': 4},
#  'winston': {'spam': 2, 'ham': 4},
#  'lghz': {'spam': 0, 'ham': 1},
#  'casewriting': {'spam': 0, 'ham': 1},
#  'pops': {'spam': 0, 'ham': 1},
#  'round': {'spam': 14, 'ham': 81},
#  'mulong': {'spam': 0, 'ham': 1},
#  'impacted': {'spam': 0, 'ham': 3},
#  'neat': {'spam': 1, 'ham': 2},
#  'aep': {'spam': 0, 'ham': 1},
#  '355': {'spam': 1, 'ham': 4},
#  'anxious': {'spam': 3, 'ham': 0},
#  'ridden': {'spam': 0, 'ham': 1},
#  'ast': {'spam': 79, 'ham': 236},
#  'cinema': {'spam': 0, 'ham': 1},
#  'exams': {'spam': 0, 'ham': 1},
#  '600': {'spam': 2, 'ham': 38},
#  '77': {'spam': 4, 'ham': 72},
#  'alot': {'spam': 0, 'ham': 2},
#  '619': {'spam': 0, 'ham': 5},
#  'slected': {'spam': 0, 'ham': 1},
#  '506': {'spam': 0, 'ham': 3},
#  '102': {'spam': 6, 'ham': 4},
#  'curran': {'spam': 0, 'ham': 3},
#  '953': {'spam': 1, 'ham': 2},
#  'inheritor': {'spam': 1, 'ham': 0},
#  'personal': {'spam': 19, 'ham': 19},
#  'inconvinence': {'spam': 0, 'ham': 1},
#  'advantages': {'spam': 2, 'ham': 3},
#  'possibilities': {'spam': 3, 'ham': 3},
#  'demianenko': {'spam': 0, 'ham': 3},
#  'lakes': {'spam': 0, 'ham': 1},
#  'gpg': {'spam': 0, 'ham': 2},
#  'dispose': {'spam': 1, 'ham': 1},
#  'edsono': {'spam': 0, 'ham': 1},
#  'giancola': {'spam': 0, 'ham': 1},
#  'holyoke': {'spam': 0, 'ham': 2},
#  'sims': {'spam': 0, 'ham': 1},
#  'sufficient': {'spam': 1, 'ham': 5},
#  'internship': {'spam': 0, 'ham': 13},
#  'pratt': {'spam': 0, 'ham': 2},
#  'timekeeper': {'spam': 0, 'ham': 1},
#  'plain': {'spam': 3, 'ham': 29},
#  'preferred': {'spam': 1, 'ham': 8},
#  'differences': {'spam': 1, 'ham': 2},
#  'pomysl': {'spam': 0, 'ham': 1},
#  'hey': {'spam': 27, 'ham': 123},
#  'origin': {'spam': 17, 'ham': 74},
#  'bagha': {'spam': 0, 'ham': 1},
#  'rico': {'spam': 0, 'ham': 1},
#  'retired': {'spam': 1, 'ham': 0},
#  'rhetorically': {'spam': 0, 'ham': 1},
#  'ineternet': {'spam': 1, 'ham': 0},
#  'priorities': {'spam': 0, 'ham': 5},
#  'mat': {'spam': 87, 'ham': 300},
#  'spinning': {'spam': 0, 'ham': 1},
#  'interactions': {'spam': 0, 'ham': 2},
#  'calibrated': {'spam': 0, 'ham': 3},
#  'reciba': {'spam': 1, 'ham': 0},
#  'meant': {'spam': 1, 'ham': 13},
#  'accomplishing': {'spam': 0, 'ham': 1},
#  'or': {'spam': 204, 'ham': 757},
#  'innovation': {'spam': 0, 'ham': 5},
#  'present': {'spam': 19, 'ham': 155},
#  'intruments': {'spam': 0, 'ham': 2},
#  'investigates': {'spam': 0, 'ham': 1},
#  'mile': {'spam': 0, 'ham': 8},
#  'inconvenience': {'spam': 2, 'ham': 5},
#  'accomplishment': {'spam': 2, 'ham': 4},
#  'inland': {'spam': 0, 'ham': 1},
#  'receive': {'spam': 46, 'ham': 111},
#  'basics': {'spam': 0, 'ham': 5},
#  'compatibility': {'spam': 0, 'ham': 1},
#  'pledelo': {'spam': 1, 'ham': 0},
#  'canadian': {'spam': 0, 'ham': 3},
#  'tried': {'spam': 9, 'ham': 10},
#  'uses': {'spam': 7, 'ham': 19},
#  'egypthttp': {'spam': 1, 'ham': 0},
#  'labbe': {'spam': 0, 'ham': 3},
#  'specialising': {'spam': 0, 'ham': 1},
#  'binary': {'spam': 0, 'ham': 2},
#  'mistake': {'spam': 2, 'ham': 5},
#  'repayment': {'spam': 0, 'ham': 1},
#  'studying': {'spam': 0, 'ham': 3},
#  'gielda': {'spam': 0, 'ham': 1},
#  'people': {'spam': 25, 'ham': 84},
#  'corresponding': {'spam': 0, 'ham': 7},
#  'loss': {'spam': 8, 'ham': 8},
#  'encotech': {'spam': 0, 'ham': 1},
#  'dpi': {'spam': 0, 'ham': 1},
#  '1994': {'spam': 0, 'ham': 2},
#  'daetz': {'spam': 0, 'ham': 1},
#  'backpack': {'spam': 1, 'ham': 0},
#  'shows': {'spam': 3, 'ham': 12},
#  'practicable': {'spam': 5, 'ham': 0},
#  'contract': {'spam': 9, 'ham': 54},
#  'accommodation': {'spam': 0, 'ham': 2},
#  'score': {'spam': 0, 'ham': 3},
#  'ourlast': {'spam': 1, 'ham': 0},
#  'naturally': {'spam': 0, 'ham': 2},
#  'ordinates': {'spam': 1, 'ham': 4},
#  'luitgard': {'spam': 0, 'ham': 1},
#  '5670': {'spam': 0, 'ham': 1},
#  'salmon': {'spam': 0, 'ham': 2},
#  'successful': {'spam': 15, 'ham': 30},
#  'dip': {'spam': 3, 'ham': 3},
#  'wesley': {'spam': 0, 'ham': 2},
#  'adv': {'spam': 36, 'ham': 102},
#  'bound': {'spam': 2, 'ham': 4},
#  'hispanic': {'spam': 2, 'ham': 0},
#  'bouillion': {'spam': 0, 'ham': 2},
#  'jonathan': {'spam': 0, 'ham': 4},
#  'suc': {'spam': 38, 'ham': 109},
#  'janie': {'spam': 0, 'ham': 1},
#  'glued': {'spam': 0, 'ham': 1},
#  'arsenal': {'spam': 1, 'ham': 0},
#  '271679': {'spam': 0, 'ham': 1},
#  'noemi': {'spam': 0, 'ham': 1},
#  'monetary': {'spam': 0, 'ham': 1},
#  'performing': {'spam': 1, 'ham': 4},
#  'dlcations': {'spam': 4, 'ham': 0},
#  'stationer': {'spam': 19, 'ham': 0},
#  'parquet': {'spam': 0, 'ham': 1},
#  'filter': {'spam': 3, 'ham': 2},
#  '5377': {'spam': 0, 'ham': 5},
#  'assumed': {'spam': 0, 'ham': 4},
#  '051102': {'spam': 1, 'ham': 0},
#  'diffusions': {'spam': 0, 'ham': 3},
#  'ebt': {'spam': 9, 'ham': 10},
#  'make': {'spam': 45, 'ham': 139},
#  'bring': {'spam': 8, 'ham': 52},
#  'multiply': {'spam': 0, 'ham': 1},
#  'ginge': {'spam': 0, 'ham': 2},
#  'rvs': {'spam': 0, 'ham': 2},
#  'screening': {'spam': 1, 'ham': 0},
#  'twenty': {'spam': 2, 'ham': 2},
#  'shi': {'spam': 38, 'ham': 223},
#  'argument': {'spam': 0, 'ham': 3},
#  'deadline': {'spam': 0, 'ham': 22},
#  '8980': {'spam': 0, 'ham': 3},
#  'cal': {'spam': 66, 'ham': 363},
#  'correction': {'spam': 0, 'ham': 5},
#  'reaiized': {'spam': 1, 'ham': 0},
#  'irs': {'spam': 25, 'ham': 114},
#  'hammers': {'spam': 0, 'ham': 1},
#  'reception': {'spam': 0, 'ham': 12},
#  'hall': {'spam': 9, 'ham': 151},
#  '0313': {'spam': 0, 'ham': 1},
#  'teknecon': {'spam': 0, 'ham': 2},
#  'tc': {'spam': 40, 'ham': 137},
#  'leftwing': {'spam': 1, 'ham': 0},
#  'downsize': {'spam': 0, 'ham': 1},
#  'transactional': {'spam': 0, 'ham': 2},
#  'chello': {'spam': 1, 'ham': 0},
#  'canyon': {'spam': 1, 'ham': 0},
#  'dinner': {'spam': 0, 'ham': 36},
#  'replacement': {'spam': 0, 'ham': 4},
#  'commonwealth': {'spam': 0, 'ham': 1},
#  'pride': {'spam': 1, 'ham': 0},
#  'likelihood': {'spam': 0, 'ham': 2},
#  'bearing': {'spam': 0, 'ham': 1},
#  'elahi': {'spam': 0, 'ham': 1},
#  'family': {'spam': 12, 'ham': 10},
#  'inforamtion': {'spam': 0, 'ham': 1},
#  'seconds': {'spam': 5, 'ham': 1},
#  'raised': {'spam': 0, 'ham': 2},
#  'ana': {'spam': 36, 'ham': 278},
#  'sees': {'spam': 2, 'ham': 3},
#  'persuaded': {'spam': 0, 'ham': 1},
#  'refinery': {'spam': 0, 'ham': 1},
#  '563': {'spam': 1, 'ham': 1},
#  'dysfunction': {'spam': 8, 'ham': 0},
#  'quaintance': {'spam': 1, 'ham': 1},
#  '972': {'spam': 0, 'ham': 7},
#  'total': {'spam': 16, 'ham': 29},
#  'ncsu': {'spam': 0, 'ham': 1},
#  'sur': {'spam': 58, 'ham': 183},
#  'mansfield': {'spam': 2, 'ham': 0},
#  'richest': {'spam': 2, 'ham': 0},
#  'additional': {'spam': 14, 'ham': 65},
#  'esource': {'spam': 10, 'ham': 60},
#  'specialised': {'spam': 0, 'ham': 1},
#  'stationery': {'spam': 19, 'ham': 0},
#  'xnd': {'spam': 1, 'ham': 0},
#  'pledged': {'spam': 0, 'ham': 1},
#  'located': {'spam': 2, 'ham': 25},
#  'outlook': {'spam': 0, 'ham': 12},
#  'monetized': {'spam': 0, 'ham': 1},
#  'flexdex': {'spam': 1, 'ham': 0},
#  'forty': {'spam': 0, 'ham': 1},
#  'chimney': {'spam': 0, 'ham': 1},
#  '5230': {'spam': 0, 'ham': 1},
#  'square': {'spam': 4, 'ham': 3},
#  'negotiator': {'spam': 0, 'ham': 1},
#  'linoleum': {'spam': 1, 'ham': 0},
#  'recognise': {'spam': 0, 'ham': 1},
#  'cancelled': {'spam': 0, 'ham': 2},
#  'buildinq': {'spam': 2, 'ham': 0},
#  'conceit': {'spam': 1, 'ham': 0},
#  'netherlands': {'spam': 1, 'ham': 0},
#  '1955': {'spam': 0, 'ham': 1},
#  'growthwrinkle': {'spam': 1, 'ham': 0},
#  '144': {'spam': 1, 'ham': 2},
#  '7917': {'spam': 0, 'ham': 1},
#  'jeden': {'spam': 0, 'ham': 1},
#  'achievements': {'spam': 0, 'ham': 1},
#  'lara': {'spam': 0, 'ham': 6},
#  'iot': {'spam': 4, 'ham': 7},
#  'usership': {'spam': 1, 'ham': 0},
#  'busch': {'spam': 2, 'ham': 0},
#  'town': {'spam': 4, 'ham': 25},
#  'kristi': {'spam': 0, 'ham': 21},
#  'rgbaz': {'spam': 1, 'ham': 0},
#  'begun': {'spam': 2, 'ham': 3},
#  'piazze': {'spam': 0, 'ham': 13},
#  'shipments': {'spam': 1, 'ham': 0},
#  'nat': {'spam': 41, 'ham': 199},
#  '6073': {'spam': 0, 'ham': 1},
#  'copia': {'spam': 1, 'ham': 0},
#  '324': {'spam': 1, 'ham': 2},
#  'manageable': {'spam': 3, 'ham': 0},
#  'burkhart': {'spam': 0, 'ham': 1},
#  'lattices': {'spam': 0, 'ham': 1},
#  'room': {'spam': 7, 'ham': 54},
#  '5967': {'spam': 0, 'ham': 1},
#  'buiiding': {'spam': 1, 'ham': 0},
#  'benjamin': {'spam': 0, 'ham': 4},
#  'annual': {'spam': 5, 'ham': 29},
#  'aol': {'spam': 5, 'ham': 28},
#  'signers': {'spam': 3, 'ham': 0},
#  'nesbitt': {'spam': 0, 'ham': 5},
#  'ots': {'spam': 3, 'ham': 12},
#  'cypress': {'spam': 0, 'ham': 1},
#  'thereafter': {'spam': 0, 'ham': 2},
#  'officers': {'spam': 1, 'ham': 4},
#  'mrs': {'spam': 0, 'ham': 1},
#  'n': {'spam': 217, 'ham': 782},
#  'fa': {'spam': 100, 'ham': 316},
#  'everyday': {'spam': 4, 'ham': 1},
#  '2050': {'spam': 0, 'ham': 1},
#  'sinha': {'spam': 0, 'ham': 1},
#  '410': {'spam': 3, 'ham': 16},
#  'indicative': {'spam': 1, 'ham': 1},
#  'aleksandra': {'spam': 0, 'ham': 1},
#  'analiza': {'spam': 0, 'ham': 1},
#  'wq': {'spam': 1, 'ham': 0},
#  'ciick': {'spam': 5, 'ham': 0},
#  'default': {'spam': 0, 'ham': 12},
#  'mepr': {'spam': 0, 'ham': 1},
#  'upgrades': {'spam': 0, 'ham': 1},
#  'pimbley': {'spam': 0, 'ham': 1},
#  'paramount': {'spam': 1, 'ham': 0},
#  'consequence': {'spam': 0, 'ham': 6},
#  'emanating': {'spam': 0, 'ham': 1},
#  '5243': {'spam': 0, 'ham': 1},
#  'whitt': {'spam': 0, 'ham': 1},
#  'evident': {'spam': 0, 'ham': 2},
#  'rod': {'spam': 42, 'ham': 131},
#  'sites': {'spam': 16, 'ham': 7},
#  'data': {'spam': 15, 'ham': 75},
#  'admiration': {'spam': 1, 'ham': 0},
#  'shane': {'spam': 0, 'ham': 2},
#  'crawling': {'spam': 1, 'ham': 0},
#  'crisp': {'spam': 1, 'ham': 1},
#  'hendon': {'spam': 0, 'ham': 3},
#  'blade': {'spam': 1, 'ham': 1},
#  'batchelder': {'spam': 0, 'ham': 1},
#  'disadvantaged': {'spam': 0, 'ham': 1},
#  'miilions': {'spam': 3, 'ham': 0},
#  'wireless': {'spam': 2, 'ham': 0},
#  'smile': {'spam': 0, 'ham': 1},
#  'swags': {'spam': 0, 'ham': 2},
#  'previously': {'spam': 2, 'ham': 9},
#  'audio': {'spam': 2, 'ham': 3},
#  'edson': {'spam': 0, 'ham': 2},
#  'sweet': {'spam': 4, 'ham': 0},
#  'mrongovia': {'spam': 0, 'ham': 1},
#  'bucket': {'spam': 1, 'ham': 4},
#  'tayana': {'spam': 1, 'ham': 0},
#  '921': {'spam': 0, 'ham': 1},
#  'agentur': {'spam': 0, 'ham': 1},
#  'charged': {'spam': 1, 'ham': 9},
#  'outagerisk': {'spam': 0, 'ham': 1},
#  'recreate': {'spam': 1, 'ham': 0},
#  'olbrzymie': {'spam': 0, 'ham': 1},
#  'touche': {'spam': 0, 'ham': 2},
#  'hires': {'spam': 0, 'ham': 10},
#  'lasting': {'spam': 1, 'ham': 2},
#  'social': {'spam': 1, 'ham': 4},
#  'cracks': {'spam': 0, 'ham': 1},
#  'dd': {'spam': 65, 'ham': 248},
#  'exeloncorp': {'spam': 0, 'ham': 1},
#  'removes': {'spam': 2, 'ham': 0},
#  'unlimited': {'spam': 13, 'ham': 0},
#  'removed': {'spam': 19, 'ham': 6},
#  'bbo': {'spam': 0, 'ham': 5},
#  '2184': {'spam': 0, 'ham': 1},
#  'problams': {'spam': 1, 'ham': 0},
#  'rhythm': {'spam': 5, 'ham': 0},
#  'whether': {'spam': 4, 'ham': 38},
#  'recepci?n': {'spam': 1, 'ham': 0},
#  'graduated': {'spam': 0, 'ham': 3},
#  '3585': {'spam': 0, 'ham': 1},
#  'fell': {'spam': 1, 'ham': 13},
#  'residents': {'spam': 2, 'ham': 4},
#  'encouraged': {'spam': 1, 'ham': 4},
#  'hsb': {'spam': 0, 'ham': 11},
#  '8877': {'spam': 0, 'ham': 1},
#  'learned': {'spam': 2, 'ham': 10},
#  'describes': {'spam': 0, 'ham': 3},
#  'ground': {'spam': 1, 'ham': 34},
#  '072': {'spam': 1, 'ham': 0},
#  'grades': {'spam': 1, 'ham': 7},
#  'italy': {'spam': 0, 'ham': 3},
#  'mediagroup': {'spam': 2, 'ham': 0},
#  'cooperation': {'spam': 3, 'ham': 9},
#  'inconstant': {'spam': 1, 'ham': 0},
#  'indirect': {'spam': 0, 'ham': 4},
#  'nxho': {'spam': 0, 'ham': 1},
#  'estimating': {'spam': 0, 'ham': 2},
#  'doliars': {'spam': 1, 'ham': 0},
#  'confidentiai': {'spam': 4, 'ham': 0},
#  'nearing': {'spam': 0, 'ham': 1},
#  'banded': {'spam': 1, 'ham': 0},
#  'robbed': {'spam': 1, 'ham': 0},
#  'netnoteinc': {'spam': 2, 'ham': 0},
#  'tristategt': {'spam': 0, 'ham': 1},
#  'foil': {'spam': 1, 'ham': 2},
#  'suite': {'spam': 13, 'ham': 19},
#  'mind': {'spam': 7, 'ham': 55},
#  'mailman': {'spam': 3, 'ham': 4},
#  'society': {'spam': 1, 'ham': 2},
#  'balloting': {'spam': 1, 'ham': 0},
#  'fiala': {'spam': 0, 'ham': 1},
#  '95': {'spam': 21, 'ham': 37},
#  'sp': {'spam': 89, 'ham': 395},
#  'thomsen': {'spam': 0, 'ham': 1},
#  'qualitative': {'spam': 0, 'ham': 1},
#  'lamas': {'spam': 0, 'ham': 6},
#  'serverhave': {'spam': 1, 'ham': 0},
#  'emarketplace': {'spam': 0, 'ham': 1},
#  'participacion': {'spam': 1, 'ham': 0},
#  'enhances': {'spam': 0, 'ham': 1},
#  'felecia': {'spam': 0, 'ham': 1},
#  'sas': {'spam': 7, 'ham': 10},
#  'yaron': {'spam': 0, 'ham': 1},
#  'jane': {'spam': 1, 'ham': 7},
#  'climate': {'spam': 0, 'ham': 1},
#  'mordaunt': {'spam': 0, 'ham': 2},
#  'cynthia': {'spam': 0, 'ham': 3},
#  'tracks': {'spam': 0, 'ham': 2},
#  'popularity': {'spam': 1, 'ham': 0},
#  'thing': {'spam': 44, 'ham': 111},
#  'prioritization': {'spam': 0, 'ham': 1},
#  'brave': {'spam': 0, 'ham': 2},
#  'isbn': {'spam': 0, 'ham': 1},
#  'capturing': {'spam': 0, 'ham': 2},
#  'gardens': {'spam': 1, 'ham': 0},
#  'dwr': {'spam': 0, 'ham': 1},
#  'instructional': {'spam': 1, 'ham': 1},
#  'blow': {'spam': 2, 'ham': 4},
#  'prepare': {'spam': 5, 'ham': 20},
#  'scicomp': {'spam': 0, 'ham': 1},
#  'fazie': {'spam': 0, 'ham': 1},
#  'heding': {'spam': 0, 'ham': 2},
#  'dwivedi': {'spam': 0, 'ham': 1},
#  'sxn': {'spam': 0, 'ham': 1},
#  'unlawful': {'spam': 1, 'ham': 1},
#  'warned': {'spam': 0, 'ham': 1},
#  'absolutely': {'spam': 7, 'ham': 5},
#  'mgm': {'spam': 1, 'ham': 10},
#  'light': {'spam': 6, 'ham': 48},
#  'seek': {'spam': 7, 'ham': 5},
#  'bassalo': {'spam': 0, 'ham': 1},
#  'curry': {'spam': 0, 'ham': 2},
#  'meg': {'spam': 5, 'ham': 5},
#  'analysed': {'spam': 0, 'ham': 1},
#  'aluminium': {'spam': 0, 'ham': 5},
#  'mercedes': {'spam': 0, 'ham': 1},
#  'qualities': {'spam': 1, 'ham': 1},
#  'alerted': {'spam': 0, 'ham': 2},
#  'further': {'spam': 17, 'ham': 57},
#  'justice': {'spam': 1, 'ham': 0},
#  '666': {'spam': 1, 'ham': 7},
#  'spreadsheet': {'spam': 0, 'ham': 20},
#  'ibm': {'spam': 1, 'ham': 2},
#  'founding': {'spam': 1, 'ham': 3},
#  'develop': {'spam': 10, 'ham': 136},
#  '7': {'spam': 76, 'ham': 475},
#  'wade': {'spam': 0, 'ham': 10},
#  'mantua': {'spam': 0, 'ham': 1},
#  '73': {'spam': 4, 'ham': 68},
#  '321': {'spam': 1, 'ham': 5},
#  'confidenti': {'spam': 11, 'ham': 35},
#  'lateral': {'spam': 2, 'ham': 3},
#  'overtime': {'spam': 0, 'ham': 2},
#  'dose': {'spam': 7, 'ham': 0},
#  'met': {'spam': 24, 'ham': 133},
#  'paradigm': {'spam': 0, 'ham': 3},
#  'quarries': {'spam': 0, 'ham': 1},
#  'jetlow': {'spam': 1, 'ham': 0},
#  'weekday': {'spam': 0, 'ham': 2},
#  'translation': {'spam': 0, 'ham': 1},
#  'mba': {'spam': 4, 'ham': 47},
#  'deakin': {'spam': 0, 'ham': 1},
#  '9326': {'spam': 0, 'ham': 1},
#  'strategic': {'spam': 0, 'ham': 23},
#  'enroll': {'spam': 1, 'ham': 4},
#  'engr': {'spam': 4, 'ham': 3},
#  'felix': {'spam': 1, 'ham': 3},
#  'corteselli': {'spam': 0, 'ham': 1},
#  'logodentity': {'spam': 1, 'ham': 0},
#  'task': {'spam': 9, 'ham': 6},
#  'walks': {'spam': 2, 'ham': 1},
#  'circular': {'spam': 0, 'ham': 2},
#  '>': {'spam': 10, 'ham': 89},
#  'perlman': {'spam': 0, 'ham': 3},
#  'discriminating': {'spam': 0, 'ham': 1},
#  'disability': {'spam': 1, 'ham': 0},
#  'keller': {'spam': 0, 'ham': 1},
#  'gaps': {'spam': 5, 'ham': 2},
#  'flying': {'spam': 0, 'ham': 6},
#  'pierce': {'spam': 0, 'ham': 2},
#  'tremendously': {'spam': 0, 'ham': 1},
#  'finalized': {'spam': 0, 'ham': 2},
#  'onshore': {'spam': 0, 'ham': 2},
#  'gutierrez': {'spam': 0, 'ham': 1},
#  'cusom': {'spam': 0, 'ham': 1},
#  'growth': {'spam': 5, 'ham': 10},
#  'lengthy': {'spam': 0, 'ham': 2},
#  'aproximately': {'spam': 0, 'ham': 1},
#  'survive': {'spam': 0, 'ham': 1},
#  '6429': {'spam': 0, 'ham': 1},
#  'may': {'spam': 38, 'ham': 209},
#  'former': {'spam': 2, 'ham': 15},
#  '7626': {'spam': 0, 'ham': 1},
#  'vehicle': {'spam': 0, 'ham': 3},
#  'stoked': {'spam': 0, 'ham': 1},
#  'blame': {'spam': 0, 'ham': 4},
#  'sager': {'spam': 0, 'ham': 1},
#  'prediction': {'spam': 1, 'ham': 1},
#  'llp': {'spam': 0, 'ham': 3},
#  'dengie': {'spam': 0, 'ham': 1},
#  'manifolds': {'spam': 0, 'ham': 1},
#  'simpson': {'spam': 0, 'ham': 3},
#  'says': {'spam': 1, 'ham': 9},
#  'lipscomb': {'spam': 0, 'ham': 1},
#  'most': {'spam': 25, 'ham': 80},
#  'forecast': {'spam': 2, 'ham': 23},
#  'organise': {'spam': 0, 'ham': 2},
#  '181': {'spam': 1, 'ham': 4},
#  'bet': {'spam': 18, 'ham': 121},
#  'sherri': {'spam': 0, 'ham': 8},
#  'johns': {'spam': 1, 'ham': 6},
#  '33461428': {'spam': 0, 'ham': 2},
#  'chauvet': {'spam': 0, 'ham': 1},
#  '5650': {'spam': 0, 'ham': 1},
#  'hurry': {'spam': 0, 'ham': 2},
#  'segments': {'spam': 1, 'ham': 2},
#  'comparably': {'spam': 1, 'ham': 0},
#  '6995': {'spam': 0, 'ham': 1},
#  'mou': {'spam': 28, 'ham': 39},
#  'postion': {'spam': 1, 'ham': 0},
#  'tao': {'spam': 0, 'ham': 2},
#  'condone': {'spam': 1, 'ham': 0},
#  'hbrett': {'spam': 0, 'ham': 1},
#  'simulation': {'spam': 0, 'ham': 13},
#  'fifty': {'spam': 1, 'ham': 1},
#  'devastating': {'spam': 0, 'ham': 1},
#  'henry': {'spam': 0, 'ham': 5},
#  'wex': {'spam': 0, 'ham': 1},
#  'ftp': {'spam': 0, 'ham': 2},
#  'proxy': {'spam': 1, 'ham': 3},
#  'ability': {'spam': 19, 'ham': 56},
#  '396': {'spam': 1, 'ham': 18},
#  'fast': {'spam': 32, 'ham': 24},
#  'opt': {'spam': 16, 'ham': 108},
#  'millions': {'spam': 9, 'ham': 3},
#  'tracey': {'spam': 0, 'ham': 1},
#  'libidoduration': {'spam': 1, 'ham': 0},
#  'handful': {'spam': 0, 'ham': 2},
#  'spamassassin': {'spam': 6, 'ham': 0},
#  'firmly': {'spam': 0, 'ham': 1},
#  '31881': {'spam': 0, 'ham': 1},
#  '271595': {'spam': 0, 'ham': 1},
#  'basak': {'spam': 0, 'ham': 1},
#  '200': {'spam': 54, 'ham': 479},
#  'bureau': {'spam': 2, 'ham': 0},
#  'yana': {'spam': 1, 'ham': 3},
#  'photograph': {'spam': 1, 'ham': 1},
#  'clauura': {'spam': 1, 'ham': 0},
#  'restricted': {'spam': 1, 'ham': 2},
#  'sequential': {'spam': 0, 'ham': 1},
#  'models': {'spam': 1, 'ham': 39},
#  'hungary': {'spam': 0, 'ham': 1},
#  'programmed': {'spam': 0, 'ham': 2},
#  'conferences': {'spam': 1, 'ham': 9},
#  'govern': {'spam': 8, 'ham': 24},
#  'alcohoi': {'spam': 1, 'ham': 0},
#  'preserve': {'spam': 0, 'ham': 1},
#  'projecct': {'spam': 0, 'ham': 1},
#  'oranjestad': {'spam': 1, 'ham': 0},
#  'selections': {'spam': 1, 'ham': 0},
#  'brainstorming': {'spam': 0, 'ham': 1},
#  'shuttle': {'spam': 0, 'ham': 3},
#  'immortal': {'spam': 1, 'ham': 0},
#  'sexually': {'spam': 1, 'ham': 0},
#  'qfs': {'spam': 0, 'ham': 2},
#  'judgement': {'spam': 1, 'ham': 1},
#  'forth': {'spam': 0, 'ham': 11},
#  'rcpt': {'spam': 1, 'ham': 0},
#  'mayo': {'spam': 1, 'ham': 1},
#  'verbally': {'spam': 0, 'ham': 4},
#  'credittrading': {'spam': 0, 'ham': 1},
#  'spoofed': {'spam': 0, 'ham': 1},
#  'musialem': {'spam': 0, 'ham': 1},
#  'discreetly': {'spam': 2, 'ham': 0},
#  'committed': {'spam': 1, 'ham': 7},
#  'lost': {'spam': 7, 'ham': 9},
#  'informational': {'spam': 0, 'ham': 2},
#  'showcase': {'spam': 1, 'ham': 1},
#  'powered': {'spam': 1, 'ham': 3},
#  'srs': {'spam': 0, 'ham': 2},
#  'designing': {'spam': 1, 'ham': 2},
#  'wspolpracujemy': {'spam': 0, 'ham': 2},
#  'explains': {'spam': 0, 'ham': 2},
#  'powerisk': {'spam': 0, 'ham': 1},
#  'thorne': {'spam': 0, 'ham': 5},
#  'bjk': {'spam': 1, 'ham': 0},
#  'quirke': {'spam': 0, 'ham': 1},
#  'indicator': {'spam': 1, 'ham': 2},
#  'jed': {'spam': 0, 'ham': 4},
#  'protocols': {'spam': 1, 'ham': 3},
#  'passage': {'spam': 1, 'ham': 1},
#  'creditor': {'spam': 1, 'ham': 5},
#  'salomon': {'spam': 0, 'ham': 2},
#  'deficits': {'spam': 0, 'ham': 1},
#  'orlando': {'spam': 0, 'ham': 1},
#  'construction': {'spam': 3, 'ham': 19},
#  'reza': {'spam': 1, 'ham': 0},
#  'pulpit': {'spam': 0, 'ham': 1},
#  'rated': {'spam': 13, 'ham': 25},
#  'downloaded': {'spam': 0, 'ham': 5},
#  'glenn': {'spam': 0, 'ham': 3},
#  'info': {'spam': 68, 'ham': 220},
#  'convictions': {'spam': 0, 'ham': 1},
#  '6861': {'spam': 0, 'ham': 1},
#  'scrapped': {'spam': 0, 'ham': 1},
#  'adoption': {'spam': 0, 'ham': 1},
#  '6855': {'spam': 0, 'ham': 1},
#  'breed': {'spam': 0, 'ham': 2},
#  'sec': {'spam': 48, 'ham': 80},
#  'hopley': {'spam': 0, 'ham': 4},
#  'frankmullers': {'spam': 1, 'ham': 0},
#  'with': {'spam': 123, 'ham': 487},
#  '020': {'spam': 4, 'ham': 9},
#  'addiontionally': {'spam': 0, 'ham': 1},
#  'kmv': {'spam': 0, 'ham': 2},
#  '6032': {'spam': 0, 'ham': 1},
#  '780': {'spam': 0, 'ham': 4},
#  'call': {'spam': 40, 'ham': 226},
#  'foundations': {'spam': 3, 'ham': 1},
#  'logos': {'spam': 8, 'ham': 0},
#  'shared': {'spam': 2, 'ham': 5},
#  'dollie': {'spam': 1, 'ham': 0},
#  'hang': {'spam': 28, 'ham': 107},
#  'destination': {'spam': 0, 'ham': 3},
#  'esai': {'spam': 0, 'ham': 4},
#  '1992': {'spam': 1, 'ham': 1},
#  'central': {'spam': 4, 'ham': 16},
#  'fee': {'spam': 31, 'ham': 131},
#  'conscious': {'spam': 1, 'ham': 1},
#  'windle': {'spam': 0, 'ham': 1},
#  'limited': {'spam': 23, 'ham': 21},
#  'equation': {'spam': 1, 'ham': 3},
#  'surrejoinder': {'spam': 1, 'ham': 0},
#  'omit': {'spam': 1, 'ham': 3},
#  'deffner': {'spam': 0, 'ham': 2},
#  'cindy': {'spam': 0, 'ham': 10},
#  'blows': {'spam': 2, 'ham': 0},
#  'fbdxq': {'spam': 0, 'ham': 1},
#  '2372': {'spam': 0, 'ham': 1},
#  'understated': {'spam': 0, 'ham': 1},
#  'energydesk': {'spam': 0, 'ham': 1},
#  '0100': {'spam': 2, 'ham': 1},
#  'jim': {'spam': 0, 'ham': 27},
#  'markus': {'spam': 0, 'ham': 3},
#  'trs': {'spam': 0, 'ham': 1},
#  'migration': {'spam': 0, 'ham': 5},
#  'late': {'spam': 23, 'ham': 142},
#  'garrett': {'spam': 0, 'ham': 1},
#  'forit': {'spam': 1, 'ham': 0},
#  'activities': {'spam': 3, 'ham': 14},
#  'phrase': {'spam': 0, 'ham': 1},
#  'arm': {'spam': 14, 'ham': 21},
#  'monitors': {'spam': 1, 'ham': 0},
#  'cialls': {'spam': 4, 'ham': 0},
#  'stephen': {'spam': 0, 'ham': 16},
#  'bermudian': {'spam': 0, 'ham': 1},
#  'aircrafts': {'spam': 0, 'ham': 1},
#  'weekend': {'spam': 0, 'ham': 27},
#  'woefully': {'spam': 0, 'ham': 1},
#  '02': {'spam': 30, 'ham': 175},
#  'bonus': {'spam': 6, 'ham': 14},
#  'shankman': {'spam': 0, 'ham': 30},
#  'trials': {'spam': 0, 'ham': 2},
#  'congressional': {'spam': 2, 'ham': 0},
#  'houstonu': {'spam': 0, 'ham': 1},
#  'hurt': {'spam': 0, 'ham': 3},
#  'scheduling': {'spam': 0, 'ham': 22},
#  'sweetness': {'spam': 1, 'ham': 0},
#  'sectors': {'spam': 3, 'ham': 5},
#  'weil': {'spam': 1, 'ham': 0},
#  'nazareth': {'spam': 0, 'ham': 2},
#  'sealed': {'spam': 0, 'ham': 3},
#  'hickerson': {'spam': 0, 'ham': 7},
#  'typesetter': {'spam': 0, 'ham': 2},
#  '100': {'spam': 28, 'ham': 45},
#  'intended': {'spam': 7, 'ham': 18},
#  'set': {'spam': 33, 'ham': 141},
#  'taichi': {'spam': 0, 'ham': 1},
#  'mississippi': {'spam': 0, 'ham': 1},
#  'etei': {'spam': 0, 'ham': 1},
#  'characterize': {'spam': 0, 'ham': 4},
#  'unhand': {'spam': 1, 'ham': 0},
#  'flawed': {'spam': 0, 'ham': 1},
#  'bigaaron': {'spam': 1, 'ham': 0},
#  'vicky': {'spam': 0, 'ham': 1},
#  'mckone': {'spam': 0, 'ham': 1},
#  'marine': {'spam': 0, 'ham': 1},
#  'relaxed': {'spam': 0, 'ham': 2},
#  'might': {'spam': 16, 'ham': 71},
#  '2965': {'spam': 0, 'ham': 2},
#  'bidding': {'spam': 0, 'ham': 3},
#  'esaulle': {'spam': 0, 'ham': 1},
#  'calpine': {'spam': 0, 'ham': 1},
#  'intermediation': {'spam': 0, 'ham': 2},
#  'india': {'spam': 1, 'ham': 23},
#  'reputation': {'spam': 0, 'ham': 1},
#  'adler': {'spam': 0, 'ham': 1},
#  '2258': {'spam': 0, 'ham': 1},
#  'freeman': {'spam': 1, 'ham': 0},
#  '339': {'spam': 0, 'ham': 3},
#  'acquisition': {'spam': 2, 'ham': 8},
#  'drop': {'spam': 3, 'ham': 4},
#  'xiao': {'spam': 0, 'ham': 3},
#  'rational': {'spam': 0, 'ham': 18},
#  '135': {'spam': 2, 'ham': 4},
#  'endowed': {'spam': 0, 'ham': 2},
#  'sharply': {'spam': 1, 'ham': 1},
#  'auctioning': {'spam': 0, 'ham': 2},
#  'bruce': {'spam': 0, 'ham': 2},
#  '8738': {'spam': 0, 'ham': 1},
#  'reaction': {'spam': 0, 'ham': 5},
#  'festivities': {'spam': 0, 'ham': 1},
#  'represented': {'spam': 0, 'ham': 4},
#  'ymjg': {'spam': 1, 'ham': 0},
#  'simon': {'spam': 0, 'ham': 8},
#  '6592': {'spam': 0, 'ham': 1},
#  'laser': {'spam': 1, 'ham': 2},
#  'grabstald': {'spam': 0, 'ham': 1},
#  'syed': {'spam': 0, 'ham': 2},
#  'historical': {'spam': 3, 'ham': 22},
#  'b': {'spam': 217, 'ham': 783},
#  'gvj': {'spam': 1, 'ham': 0},
#  'slapped': {'spam': 0, 'ham': 1},
#  'entrants': {'spam': 0, 'ham': 1},
#  'ordering': {'spam': 4, 'ham': 4},
#  'acpw': {'spam': 0, 'ham': 1},
#  'meaningful': {'spam': 0, 'ham': 6},
#  'przed': {'spam': 0, 'ham': 2},
#  'lew': {'spam': 1, 'ham': 23},
#  'terminating': {'spam': 0, 'ham': 1},
#  'organizer': {'spam': 0, 'ham': 2},
#  'smartmortgageusa': {'spam': 2, 'ham': 0},
#  'obi': {'spam': 5, 'ham': 13},
#  'resumes': {'spam': 0, 'ham': 5},
#  'cop': {'spam': 21, 'ham': 113},
#  'fall': {'spam': 4, 'ham': 28},
#  'grand': {'spam': 3, 'ham': 3},
#  'pecos': {'spam': 0, 'ham': 1},
#  'ob': {'spam': 51, 'ham': 298},
#  'ionqing': {'spam': 1, 'ham': 0},
#  'swisher': {'spam': 0, 'ham': 1},
#  'must': {'spam': 20, 'ham': 33},
#  '4592': {'spam': 0, 'ham': 1},
#  'twice': {'spam': 1, 'ham': 2},
#  'wants': {'spam': 2, 'ham': 24},
#  'charities': {'spam': 0, 'ham': 1},
#  'competing': {'spam': 0, 'ham': 2},
#  'px': {'spam': 0, 'ham': 5},
#  'turn': {'spam': 41, 'ham': 70},
#  'kulatilaka': {'spam': 0, 'ham': 1},
#  'demise': {'spam': 1, 'ham': 0},
#  'reliantenergy': {'spam': 0, 'ham': 2},
#  'gwyn': {'spam': 0, 'ham': 5},
#  'stainlessteelbody': {'spam': 1, 'ham': 0},
#  'warranty': {'spam': 1, 'ham': 0},
#  '7517': {'spam': 1, 'ham': 0},
#  'pgpfreeware': {'spam': 0, 'ham': 1},
#  'scout': {'spam': 0, 'ham': 1},
#  'escape': {'spam': 1, 'ham': 2},
#  'subscribe': {'spam': 19, 'ham': 10},
#  'some': {'spam': 37, 'ham': 245},
#  'guaiity': {'spam': 1, 'ham': 0},
#  '7260': {'spam': 0, 'ham': 1},
#  'diversification': {'spam': 0, 'ham': 2},
#  'chodzi': {'spam': 0, 'ham': 1},
#  'russell': {'spam': 0, 'ham': 4},
#  'cliff': {'spam': 0, 'ham': 3},
#  'table': {'spam': 16, 'ham': 46},
#  '33145': {'spam': 2, 'ham': 0},
#  'mer': {'spam': 54, 'ham': 235},
#  'develoment': {'spam': 0, 'ham': 1},
#  'asp': {'spam': 1, 'ham': 13},
#  'monte': {'spam': 0, 'ham': 12},
#  'stearns': {'spam': 0, 'ham': 2},
#  'offered': {'spam': 3, 'ham': 13},
#  'underlyings': {'spam': 0, 'ham': 1},
#  '43': {'spam': 10, 'ham': 48},
#  'blaming': {'spam': 0, 'ham': 1},
#  '9611': {'spam': 0, 'ham': 2},
#  'lesley': {'spam': 0, 'ham': 1},
#  'distribute': {'spam': 3, 'ham': 14},
#  'amex': {'spam': 1, 'ham': 0},
#  'getting': {'spam': 15, 'ham': 35},
#  'fis': {'spam': 4, 'ham': 6},
#  'muscle': {'spam': 4, 'ham': 0},
#  'sa': {'spam': 147, 'ham': 434},
#  'wealth': {'spam': 2, 'ham': 3},
#  'nate': {'spam': 14, 'ham': 66},
#  '24406': {'spam': 0, 'ham': 1},
#  'sept': {'spam': 2, 'ham': 20},
#  'developed': {'spam': 2, 'ham': 27},
#  'undone': {'spam': 0, 'ham': 1},
#  'wkshp': {'spam': 0, 'ham': 1},
#  'herein': {'spam': 4, 'ham': 1},
#  'proportionately': {'spam': 0, 'ham': 1},
#  'acknowledgement': {'spam': 0, 'ham': 2},
#  'brysonpa': {'spam': 0, 'ham': 1},
#  'authorization': {'spam': 1, 'ham': 7},
#  'kirby': {'spam': 0, 'ham': 1},
#  'tender': {'spam': 1, 'ham': 0},
#  'chemist': {'spam': 1, 'ham': 0},
#  'bumps': {'spam': 0, 'ham': 1},
#  '244': {'spam': 1, 'ham': 3},
#  'roch': {'spam': 1, 'ham': 19},
#  'wykorzystywanych': {'spam': 0, 'ham': 1},
#  'alterations': {'spam': 0, 'ham': 1},
#  'georgel': {'spam': 1, 'ham': 0},
#  'ceska': {'spam': 0, 'ham': 1},
#  'pioneers': {'spam': 0, 'ham': 1},
#  'north': {'spam': 1, 'ham': 57},
#  'interested': {'spam': 28, 'ham': 91},
#  'actually': {'spam': 7, 'ham': 18},
#  'confidencialidad': {'spam': 1, 'ham': 0},
#  'letter': {'spam': 14, 'ham': 44},
#  'earliest': {'spam': 2, 'ham': 9},
#  'toy': {'spam': 1, 'ham': 0},
#  'deposits': {'spam': 4, 'ham': 0},
#  'investigate': {'spam': 2, 'ham': 3},
#  '8850': {'spam': 0, 'ham': 3},
#  'buynxlc': {'spam': 1, 'ham': 0},
#  'finalizing': {'spam': 0, 'ham': 4},
#  '626': {'spam': 1, 'ham': 2},
#  'hq': {'spam': 0, 'ham': 1},
#  '954': {'spam': 1, 'ham': 3},
#  'closet': {'spam': 1, 'ham': 0},
#  'kindall': {'spam': 0, 'ham': 17},
#  'fuel': {'spam': 3, 'ham': 9},
#  'undoubtedly': {'spam': 1, 'ham': 0},
#  'enel': {'spam': 0, 'ham': 2},
#  'solved': {'spam': 0, 'ham': 9},
#  'carolina': {'spam': 0, 'ham': 4},
#  'reliable': {'spam': 4, 'ham': 1},
#  'evan': {'spam': 2, 'ham': 21},
#  'structured': {'spam': 0, 'ham': 15},
#  'suites': {'spam': 1, 'ham': 0},
#  'schoemaker': {'spam': 0, 'ham': 1},
#  'mw': {'spam': 6, 'ham': 19},
#  'akin': {'spam': 12, 'ham': 89},
#  'turnaround': {'spam': 5, 'ham': 0},
#  'airport': {'spam': 1, 'ham': 4},
#  'habiba': {'spam': 0, 'ham': 1},
#  'dailyupdate': {'spam': 0, 'ham': 1},
#  'coveted': {'spam': 1, 'ham': 0},
#  'sin': {'spam': 96, 'ham': 322},
#  'leakages': {'spam': 0, 'ham': 1},
#  'ation': {'spam': 120, 'ham': 553},
#  'appears': {'spam': 1, 'ham': 10},
#  '62': {'spam': 13, 'ham': 60},
#  'sengupta': {'spam': 0, 'ham': 2},
#  'maxed': {'spam': 0, 'ham': 1},
#  'lightning': {'spam': 1, 'ham': 0},
#  'abacus': {'spam': 0, 'ham': 1},
#  'stuffed': {'spam': 1, 'ham': 0},
#  'boldly': {'spam': 1, 'ham': 1},
#  'hoog': {'spam': 0, 'ham': 2},
#  'sycamore': {'spam': 0, 'ham': 2},
#  'drugie': {'spam': 0, 'ham': 2},
#  'unequal': {'spam': 0, 'ham': 4},
#  'began': {'spam': 2, 'ham': 2},
#  'why': {'spam': 14, 'ham': 9},
#  'treading': {'spam': 0, 'ham': 1},
#  'pdt': {'spam': 0, 'ham': 2},
#  'reflect': {'spam': 5, 'ham': 14},
#  'wiley': {'spam': 0, 'ham': 3},
#  'west': {'spam': 6, 'ham': 33},
#  'degiacic': {'spam': 0, 'ham': 1},
#  'abide': {'spam': 0, 'ham': 2},
#  'paths': {'spam': 0, 'ham': 4},
#  'hara': {'spam': 3, 'ham': 25},
#  'tasks': {'spam': 2, 'ham': 1},
#  'omnicom': {'spam': 0, 'ham': 1},
#  'keeping': {'spam': 1, 'ham': 7},
#  'iom': {'spam': 0, 'ham': 3},
#  '349': {'spam': 1, 'ham': 2},
#  'slippery': {'spam': 0, 'ham': 1},
#  'krogmeier': {'spam': 0, 'ham': 1},
#  'decrement': {'spam': 0, 'ham': 1},
#  'publish': {'spam': 6, 'ham': 24},
#  'revolutionize': {'spam': 0, 'ham': 1},
#  'advisor': {'spam': 7, 'ham': 19},
#  'royalties': {'spam': 0, 'ham': 2},
#  'fri': {'spam': 21, 'ham': 139},
#  'fullest': {'spam': 1, 'ham': 0},
#  'drinks': {'spam': 0, 'ham': 1},
#  '4026': {'spam': 0, 'ham': 2},
#  'woodybc': {'spam': 0, 'ham': 1},
#  'rosenkopf': {'spam': 0, 'ham': 1},
#  'spice': {'spam': 0, 'ham': 1},
#  '34073': {'spam': 0, 'ham': 1},
#  'econometric': {'spam': 0, 'ham': 3},
#  'machines': {'spam': 2, 'ham': 2},
#  'ms': {'spam': 59, 'ham': 232},
#  'elo': {'spam': 44, 'ham': 228},
#  'macromedia': {'spam': 8, 'ham': 1},
#  ...}

# %%
# Test your model with some words
# Examples: 'lottery', 'sale', 'meeting'

# %% [markdown]
# ## Step 5: Implementing the Prediction Function
# Finally, let's implement the function to predict whether an email is spam.

# %%
def predict_naive_bayes(email_text, model, num_spam, num_ham):
    """
    Predict whether an email is spam using Naive Bayes
    
    Parameters:
        email_text (str): The text of the email to classify
        model (dict): Trained Naive Bayes model
        num_spam (int): Number of spam emails in training data
        num_ham (int): Number of ham emails in training data
    
    Returns:
        float: Probability that the email is spam
    """
    # TODO: Implement the Naive Bayes prediction
    # 1. Preprocess the email text
    # 2. Calculate probability using the Naive Bayes formula

    # Your code here
    text = process_email(email_text)
    pro = []
    for i in text:
        if i in words:
            k1 = [(model[i]["spam"])*spam_probability/((model[i]["spam"])*spam_probability+(model[i]["ham"])*(1-spam_probability))]
            pro.append(k1)
    PROB = 1
    float(PROB)
    pro =  [element for innerList in pro for element in innerList]
    for i in pro:
        PROB = PROB*i
    return PROB

    # HINT: Use the log of probabilities to avoid numerical underflow
    # HINT: Remember to handle words not in the training data
    pass

# %%
# Test your prediction function
test_emails = [
    "lottery winner claim prize money",
    "meeting tomorrow at 3pm",
    "buy cheap watches online"
]

# %%
email_text = "lottery winner claim prize money"

# %%
predict_naive_bayes(email_text, model, num_spam, num_ham)
# Out:
# 0.002081042230870518

# %% [markdown]
# ## Step 6: Wrap-up
# 1. How well did your model perform?
# 2. What challenges did you face while implementing it from scratch?
# 3. What improvements would you suggest for the future?

# %% [markdown]
# ### Notes (if any): The model will perform as required if whole of the dataset is taken as to process huge dataset my code block is taking more than required time because of which I sliced the data if you can please provide optimal solution and neglect model's performance for now
